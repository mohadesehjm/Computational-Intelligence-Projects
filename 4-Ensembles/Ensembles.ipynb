# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import AdaBoostClassifier
from sklearn import datasets
from sklearn import metrics
# from random import shuffle
from sklearn.utils import shuffle

# %%
with open('project/pairsDevTrain.txt','r') as f:
    lines = f.readlines()

# %%
with open('project/pairsDevTest.txt','r') as f:
    lines_test = f.readlines()

# %%
counter = int(lines[0].replace('\n'," "))
name = []
index1 = []
index2 = []
for i in range(1,counter+1):
    test = lines[i].split("\t")
    n = test[0]
    i1 = test[1]
    i2 = test[2].split("\n")[0]
    name.append(n)
    index1.append(i1)
    index2.append(i2)
    
name1 = []
name2 = []
index3 = []
index4 = []
for i in range(counter+1,2*counter+1):
    test = lines[i].split("\t")
    n1 = test[0]
    n2 = test[2]
    i1 = test[1]
    i2 = test[3].split("\n")[0]
    name1.append(n1)
    name2.append(n2)
    index3.append(i1)
    index4.append(i2)

# %%
# test dataset
counter_test = int(lines_test[0].replace('\n'," "))
name_test = []
index1_test = []
index2_test = []
for i in range(1,counter_test+1):
    test = lines_test[i].split("\t")
    n = test[0]
    i1 = test[1]
    i2 = test[2].split("\n")[0]
    name_test.append(n)
    index1_test.append(i1)
    index2_test.append(i2)
    
name1_test = []
name2_test = []
index3_test = []
index4_test = []
for i in range(counter_test+1,2*counter_test+1):
    test = lines_test[i].split("\t")
    n1 = test[0]
    n2 = test[2]
    i1 = test[1]
    i2 = test[3].split("\n")[0]
    name1_test.append(n1)
    name2_test.append(n2)
    index3_test.append(i1)
    index4_test.append(i2)

# %%
d = {'name': name, 'pic1':index1, 'pic2':index2,'fet1':'','fet2':'','label':1}
df = pd.DataFrame(data=d)
df
# Out:
#                      name pic1 pic2 fet1 fet2  label
# 0           Aaron_Peirsol    1    2                1
# 1           Aaron_Peirsol    3    4                1
# 2            Aaron_Sorkin    1    2                1
# 3     Abdel_Nasser_Assidi    1    2                1
# 4                Abdullah    1    3                1
# ...                   ...  ...  ...  ...  ...    ...
# 1095           Zhu_Rongji    1    9                1
# 1096           Zhu_Rongji    4    7                1
# 1097           Zhu_Rongji    4    8                1
# 1098           Zhu_Rongji    5    6                1
# 1099      Zinedine_Zidane    2    4                1
#
# [1100 rows x 6 columns]

# %%
d1 = {'name': name1, 'name2':name2 ,'pic1':index3, 'pic2':index4,'fet1':'','fet2':'','label':0}
df_2 = pd.DataFrame(data=d1)
df_2
# Out:
#                      name                 name2 pic1 pic2 fet1 fet2  label
# 0                 AJ_Cook       Marsha_Thomason    1    1                0
# 1            Aaron_Sorkin          Frank_Solich    2    5                0
# 2     Abdel_Nasser_Assidi          Hilary_McKay    2    1                0
# 3          Abdoulaye_Wade            Linda_Dano    4    1                0
# 4            Abdul_Rahman           Magui_Serna    1    1                0
# ...                   ...                   ...  ...  ...  ...  ...    ...
# 1095          Tom_Vilsack        Wayne_Ferreira    1    5                0
# 1096         Trisha_Meili  Vladimiro_Montesinos    1    3                0
# 1097             Ty_Votaw          Wayne_Allard    1    1                0
# 1098       Vytas_Danelius        Zaini_Abdullah    1    1                0
# 1099        Wendy_Kennedy        Zara_Akhmadova    1    1                0
#
# [1100 rows x 7 columns]

# %%
d = {'name': name_test, 'pic1':index1_test, 'pic2':index2_test,'fet1':'','fet2':'','label':1}
df_test = pd.DataFrame(data=d)
df_test
# Out:
#                    name pic1 pic2 fet1 fet2  label
# 0          Abdullah_Gul   13   14                1
# 1          Abdullah_Gul   13   16                1
# 2      Abdullatif_Sener    1    2                1
# 3        Adel_Al-Jubeir    1    3                1
# 4             Al_Pacino    1    2                1
# ..                  ...  ...  ...  ...  ...    ...
# 495        Winona_Ryder    6   15                1
# 496        Winona_Ryder   19   21                1
# 497  Yevgeny_Kafelnikov    3    4                1
# 498    Yoriko_Kawaguchi    3   10                1
# 499      Zoran_Djindjic    3    4                1
#
# [500 rows x 6 columns]

# %%
d1 = {'name': name1_test, 'name2':name2_test ,'pic1':index3_test, 'pic2':index4_test,'fet1':'','fet2':'','label':0}
df_2_test = pd.DataFrame(data=d1)
df_2_test
# Out:
#                             name                         name2 pic1 pic2 fet1  \
# 0                       AJ_Lamas                   Zach_Safrin    1    1
# 1                    Aaron_Guiel             Reese_Witherspoon    1    3
# 2                   Aaron_Tippin  Jose_Luis_Rodriguez_Zapatero    1    1
# 3         Abdul_Majeed_Shobokshi                  Charles_Cope    1    1
# 4                   Abdullah_Gul                     Steve_Cox   16    1
# ..                           ...                           ...  ...  ...  ...
# 495                 Susan_Whelan         Wolfgang_Schneiderhan    1    1
# 496                  Takeo_Fukui               Will_Ofenheusle    1    1
# 497                 Tamara_Mowry                   Zach_Parise    1    1
# 498  Tatiana_Kennedy_Schlossberg                 Thomas_Watjen    1    1
# 499                   Todd_Petit             Vicente_Fernandez    1    3
#
#     fet2  label
# 0             0
# 1             0
# 2             0
# ...

# %%
a2 = []
for i in range(counter):
    name = df['name'][i]
    pic1 = pic2 = test = test1 = ''
    a1 = []
    if int(df['pic1'][i]) >= 100:
        pic1 = name + '_' + '0'+ df['pic1'][i]
    elif 99>= int(df['pic1'][i]) >= 10:
        pic1 = name + '_' + '00'+ df['pic1'][i]
    else :
        pic1 = name + '_' + '000'+ df['pic1'][i]
        
    if int(df['pic2'][i]) >= 100 :
        pic2 = name + '_' + '0'+ df['pic2'][i]
    elif 99>int(df['pic2'][i]) >= 10 :
        pic2 = name + '_' + '00'+ df['pic2'][i]
    else :
        pic2 = name + '_' + '000'+ df['pic2'][i]
    with open('project/lfw/'+name+'/' +pic1 +'.txt','r') as f:
        test = f.read()
        df['fet1'][i] =  test
        test = test.split("[[")[1]
        arr = test.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else: 
                a1.append(float(arr[i]))
        
        
    with open('project/lfw/'+name+'/' +pic2 +'.txt','r') as f:
        test1 = f.read()
        df['fet2'][i] =  test1
        test1 = test1.split("[[")[1]
        arr = test1.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else: 
                a1.append(float(arr[i]))
                
                
    a2.append(a1)
# Out:
# /Users/mohadeseh/Documents/old_photo_restoration/code/Img_to_Img/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/mohadeseh/Documents/old_photo_restoration/code/Img_to_Img/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:38: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df
# Out:
#                      name pic1 pic2  \
# 0           Aaron_Peirsol    1    2
# 1           Aaron_Peirsol    3    4
# 2            Aaron_Sorkin    1    2
# 3     Abdel_Nasser_Assidi    1    2
# 4                Abdullah    1    3
# ...                   ...  ...  ...
# 1095           Zhu_Rongji    1    9
# 1096           Zhu_Rongji    4    7
# 1097           Zhu_Rongji    4    8
# 1098           Zhu_Rongji    5    6
# 1099      Zinedine_Zidane    2    4
#
#                                                    fet1 fet2  label
# 0     [[9.43082690e-01 3.28069896e-01 5.10735512e+00...           1
# 1     [[1.45405674e+00 2.05314040e+00 1.51097548e+00...           1
# 2     [[1.52582908e+00 2.11960840e+00 1.20013811e-01...           1
# 3     [[8.1341374e-01 2.6844177e+00 1.7458496e+00 2....           1
# 4     [[8.99211824e-01 3.87123108e+00 4.04598093e+00...           1
# ...                                                 ...  ...    ...
# ...

# %%
a3 = []

for i in range(counter):
#     print("i", i)
    name1 = df_2['name'][i]
    name2 = df_2['name2'][i]
    pic1 = pic2 = test = test1 = ''
    a1 = []
    if int(df_2['pic1'][i]) >= 100:
        pic1 = name1 + '_' + '0'+ df_2['pic1'][i]
    elif 99>= int(df_2['pic1'][i]) >= 10:
        pic1 = name1 + '_' + '00'+ df_2['pic1'][i]
    else :
        pic1 = name1 + '_' + '000'+ df_2['pic1'][i]
        
    if int(df_2['pic2'][i]) >= 100 :
        pic2 = name2 + '_' + '0'+ df_2['pic2'][i]
    elif 99>int(df_2['pic2'][i]) >= 10 :
        pic2 = name2 + '_' + '00'+ df_2['pic2'][i]
    else :
        pic2 = name2 + '_' + '000'+ df_2['pic2'][i]
    with open('project/lfw/'+name1+'/' +pic1 +'.txt','r') as f:
        test = f.read()
        df_2['fet1'][i] = test
        test = test.split("[[")[1]
        arr = test.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else: 
                a1.append(float(arr[i]))     
    with open('project/lfw/'+name2+'/' +pic2 +'.txt','r') as f:
        test1 = f.read()
        df_2['fet2'][i] =  test1
        test1 = test1.split("[[")[1]
        arr = test1.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else:
                a1.append(float(arr[i]))
    a3.append(a1)
# Out:
# /Users/mohadeseh/Documents/old_photo_restoration/code/Img_to_Img/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/mohadeseh/Documents/old_photo_restoration/code/Img_to_Img/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# test
a2_test = []
for i in range(counter_test):
    name = df_test['name'][i]
    pic1 = pic2 = test = test1 = ''
    a1 = []
    if int(df_test['pic1'][i]) >= 100:
        pic1 = name + '_' + '0'+ df_test['pic1'][i]
    elif 99>= int(df_test['pic1'][i]) >= 10:
        pic1 = name + '_' + '00'+ df_test['pic1'][i]
    else :
        pic1 = name + '_' + '000'+ df_test['pic1'][i]
        
    if int(df_test['pic2'][i]) >= 100 :
        pic2 = name + '_' + '0'+ df_test['pic2'][i]
    elif 99>int(df_test['pic2'][i]) >= 10 :
        pic2 = name + '_' + '00'+ df_test['pic2'][i]
    else :
        pic2 = name + '_' + '000'+ df_test['pic2'][i]
    with open('project/lfw/'+name+'/' +pic1 +'.txt','r') as f:
        test = f.read()
        df_test['fet1'][i] =  test
        test = test.split("[[")[1]
        arr = test.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else: 
                a1.append(float(arr[i]))
        
        
    with open('project/lfw/'+name+'/' +pic2 +'.txt','r') as f:
        test1 = f.read()
        df_test['fet2'][i] =  test1
        test1 = test1.split("[[")[1]
        arr = test1.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else: 
                a1.append(float(arr[i]))
                
                
    a2_test.append(a1)
# Out:
# /Users/mohadeseh/Documents/old_photo_restoration/code/Img_to_Img/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/mohadeseh/Documents/old_photo_restoration/code/Img_to_Img/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
a3_test = []

for i in range(counter_test):
#     print("i", i)
    name1 = df_2_test['name'][i]
    name2 = df_2_test['name2'][i]
    pic1 = pic2 = test = test1 = ''
    a1 = []
    if int(df_2_test['pic1'][i]) >= 100:
        pic1 = name1 + '_' + '0'+ df_2_test['pic1'][i]
    elif 99>= int(df_2_test['pic1'][i]) >= 10:
        pic1 = name1 + '_' + '00'+ df_2_test['pic1'][i]
    else :
        pic1 = name1 + '_' + '000'+ df_2_test['pic1'][i]
        
    if int(df_2_test['pic2'][i]) >= 100 :
        pic2 = name2 + '_' + '0'+ df_2_test['pic2'][i]
    elif 99>int(df_2_test['pic2'][i]) >= 10 :
        pic2 = name2 + '_' + '00'+ df_2_test['pic2'][i]
    else :
        pic2 = name2 + '_' + '000'+ df_2_test['pic2'][i]
    with open('project/lfw/'+name1+'/' +pic1 +'.txt','r') as f:
        test = f.read()
        df_2_test['fet1'][i] = test
        test = test.split("[[")[1]
        arr = test.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else: 
                a1.append(float(arr[i]))     
    with open('project/lfw/'+name2+'/' +pic2 +'.txt','r') as f:
        test1 = f.read()
        df_2_test['fet2'][i] =  test1
        test1 = test1.split("[[")[1]
        arr = test1.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else:
                a1.append(float(arr[i]))
    a3_test.append(a1)
# Out:
# /Users/mohadeseh/Documents/old_photo_restoration/code/Img_to_Img/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /Users/mohadeseh/Documents/old_photo_restoration/code/Img_to_Img/miniconda3/lib/python3.7/site-packages/ipykernel_launcher.py:39: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# arr = test.replace("\n","").split(" ")
# len(arr)
# a1 = []
# a2 = []
# for i in range(len(arr)):
#     if arr[i] == '' :
#         pass
#     elif i == 0 :
#         t = arr[i].split("[[")
#         a1.append(float(t[1]))
#     elif i == len(arr)-1:
#         t = arr[i].split("]]")
#         a1.append(float(t[0]))
#     else: 
#         a1.append(float(arr[i]))
            
# a2

# %%
# arr = test1.replace("\n","").split(" ")
# len(arr)
# for i in range(len(arr)):
#     if arr[i] == '' :
#         pass
#     elif i == 0 :
#         t = arr[i].split("[[")
#         a1.append(float(t[1]))
#     elif i == len(arr)-1:
#         t = arr[i].split("]]")
#         a1.append(float(t[0]))
#     else: 
#         a1.append(float(arr[i]))
        
# len(a1)

# %%
df_2.to_csv("df_2.csv")
df.to_csv("df.csv")

# %%
# a2 = np.reshape(a1, (1, 1024))

# np.shape(a2)

# %%
# X_train = pd.concat([df.iloc[:,3:],df_2.iloc[:,4:]],axis=0)
X_train1 = pd.DataFrame(a2)
X_train1
X_train2 = pd.DataFrame(a3)
X_train2
X1 = pd.concat([X_train1,df.iloc[:,5]],axis=1)
X1
X2 = pd.concat([X_train2,df_2.iloc[:,6]],axis=1)
X2

X_train = pd.concat([X1,X2],axis=0)
X_train
# Out:
#              0         1         2         3         4          5          6  \
# 0     0.943083  0.328070  5.107355  0.047781  6.151414   6.137378   2.698583
# 1     1.454057  2.053140  1.510975  0.300200  4.056980   2.742740   2.834798
# 2     1.525829  2.119608  0.120014  1.431045  4.351317   9.113686   6.806141
# 3     0.813414  2.684418  1.745850  0.257840  1.472835   3.998883   1.697413
# 4     0.899212  3.871231  4.045981  0.206819  7.851793   4.136694   2.494328
# ...        ...       ...       ...       ...       ...        ...        ...
# 1095  2.124551  0.135523  1.459448  0.120547  0.647721  14.389665   4.694295
# 1096  0.236122  1.186276  1.977578  0.000000  1.251430   2.024422   6.032820
# 1097  2.326176  3.522727  2.265609  0.000000  0.416707   2.480762   4.914556
# 1098  3.678269  0.119461  1.438015  0.777253  0.158648   5.477327   4.505041
# 1099  0.000000  1.346309  2.808309  1.332433  0.039468   7.065207  12.230016
#
# ...

# %%
X_test1 = pd.DataFrame(a2_test)

X_test2 = pd.DataFrame(a3_test)
X_test1
X1 = pd.concat([X_test1,df_test.iloc[:,5]],axis=1)

X2 = pd.concat([X_test2,df_2_test.iloc[:,6]],axis=1)


X_test = pd.concat([X1,X2],axis=0)
X_test
# Out:
#             0         1          2         3          4         5         6  \
# 0    1.349706  1.197813   1.866544  0.003267   0.797498  7.253777  7.998175
# 1    1.349706  1.197813   1.866544  0.003267   0.797498  7.253777  7.998175
# 2    0.741477  0.922977   0.962432  0.027037   0.570898  0.190039  0.821979
# 3    1.148699  1.305753   0.797906  0.020593   0.000000  9.680884  6.672922
# 4    0.069380  0.000000   2.994990  0.000000   1.400044  4.814030  8.961414
# ..        ...       ...        ...       ...        ...       ...       ...
# 495  3.039391  0.032237   1.298288  2.453755   2.927109  2.329246  5.348336
# 496  0.900691  0.000000   3.376374  0.474559   0.000000  1.525415  2.281301
# 497  3.055318  1.045660   2.981344  0.082576   5.805265  0.587725  1.721573
# 498  0.795895  0.543751  14.022307  2.906320  14.261437  1.496604  3.439011
# 499  0.693673  0.026308   0.075736  0.631874   0.000000  3.279488  0.707745
#
# ...

# %%
# from sklearn.utils import shuffle
X_train = shuffle(X_train)
X_train
# Out:
#              0         1         2         3          4         5          6  \
# 936   0.840214  1.133730  0.315865  0.659757   6.133272  2.047568   1.579147
# 92    0.513667  1.099682  4.855259  0.000000   0.000000  2.462458   6.092745
# 82    6.472105  2.629111  3.951909  1.803867   1.457680  5.413683   4.559505
# 1063  0.083490  6.792426  1.295807  4.917516   0.000000  6.456467  10.660556
# 481   0.006633  1.235489  1.382598  0.000000   0.000000  3.110750   6.419797
# ...        ...       ...       ...       ...        ...       ...        ...
# 1041  0.930236  0.000000  6.964284  0.444715   0.104426  1.502980   4.361663
# 236   2.668381  5.264920  0.841472  0.000000   1.812070  6.759550   3.382093
# 8     0.035558  2.883478  0.120854  0.491002   0.023132  3.316186   7.264543
# 325   2.089953  2.995430  5.231751  0.268079  10.360258  1.787884   7.567027
# 340   1.531960  0.845151  3.143677  2.246707   0.988064  1.426177   4.909493
#
# ...

# %%
X_train_new = X_train.iloc[:1800,:1024]
Y_train = X_train.iloc[:1800,1024]
Y_train
X_Val = X_train.iloc[1800:,:1024]
Y_Val = X_train.iloc[1800:,1024]
Y_Val
# Out:
# 641     0
# 400     1
# 260     0
# 1036    0
# 724     0
#        ..
# 1041    1
# 236     0
# 8       0
# 325     0
# 340     1
# Name: label, Length: 400, dtype: int64

# %%
X_test = shuffle(X_test)
X_test
# Out:
#             0         1         2         3          4          5         6  \
# 123  1.081124  2.105504  4.717862  0.106374   1.956316   1.867515  2.240669
# 282  0.000000  0.048030  6.622246  0.678983   1.060170   1.146087  3.525057
# 177  1.092697  0.000000  3.500646  0.851553   1.328887   1.700756  2.989259
# 433  0.427176  2.262149  0.648438  0.917862   0.667063   3.426016  2.176629
# 311  1.202580  0.546504  0.000000  0.218297   1.154707   1.235678  5.224761
# ..        ...       ...       ...       ...        ...        ...       ...
# 58   3.210928  0.037239  1.787044  2.581226   0.218869   1.061760  2.369663
# 400  0.000000  1.700683  0.366900  0.834489   1.390690   1.523242  4.670046
# 167  0.586020  2.603369  4.126535  0.000000  12.329211   1.332874  4.954087
# 103  0.212368  1.386686  0.800172  0.102175   2.841343  11.866301  5.080979
# 220  4.422577  0.758608  1.086672  0.324208   1.247715  10.075734  3.365420
#
# ...

# %%
X_test_new = X_train.iloc[:,:1024]
Y_test = X_train.iloc[:,1024]
Y_test
# Out:
# 936     1
# 92      0
# 82      0
# 1063    0
# 481     0
#        ..
# 1041    1
# 236     0
# 8       0
# 325     0
# 340     1
# Name: label, Length: 2200, dtype: int64

# %%
# 5749
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier(random_state=0, max_depth=2)
abc = AdaBoostClassifier(base_estimator=decision_tree, n_estimators=200,learning_rate=1)

# Train Adaboost Classifer
model = abc.fit(X_train_new, Y_train)

# %%
#Predict the response for test dataset
y_pred = model.predict(X_test_new)

# %%
print("Training_Accuracy:",metrics.accuracy_score(Y_train,model.predict(X_train_new)))
print("Testing Accuracy:",metrics.accuracy_score(Y_test, y_pred))
print("Validation_Accuracy:",metrics.accuracy_score(Y_Val,model.predict(X_Val)))
# Out:
# Training_Accuracy: 1.0
# Testing Accuracy: 0.9472727272727273
# Validation_Accuracy: 0.71

# %% [markdown]
# # AdaBoost with SVC

# %%
# Load libraries
from sklearn.ensemble import AdaBoostClassifier

# Import Support Vector Classifier
from sklearn.svm import SVC
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
svc=SVC(probability=True, kernel='rbf')

# Create adaboost classifer object
abc =AdaBoostClassifier(n_estimators=150, base_estimator=svc,learning_rate=1)

# Train Adaboost Classifer
model = abc.fit(X_train_new, Y_train)

#Predict the response for test dataset
y_pred = model.predict(X_test_new)

# %%
print("Training_Accuracy:",metrics.accuracy_score(Y_train,model.predict(X_train_new)))
print("Testing Accuracy:",metrics.accuracy_score(Y_test, y_pred))
print("Validation_Accuracy:",metrics.accuracy_score(Y_Val,model.predict(X_Val)))
# Out:
# Training_Accuracy: 0.9994318181818181
# Testing Accuracy: 0.9481818181818182
# Validation_Accuracy: 0.7431818181818182

# %%
X_train_new
# Out:
#           0         1         2         3         4          5          6     \
# 936   0.840214  1.133730  0.315865  0.659757  6.133272   2.047568   1.579147
# 92    0.513667  1.099682  4.855259  0.000000  0.000000   2.462458   6.092745
# 82    6.472105  2.629111  3.951909  1.803867  1.457680   5.413683   4.559505
# 1063  0.083490  6.792426  1.295807  4.917516  0.000000   6.456467  10.660556
# 481   0.006633  1.235489  1.382598  0.000000  0.000000   3.110750   6.419797
# ...        ...       ...       ...       ...       ...        ...        ...
# 681   1.892402  5.862087  6.564034  0.000000  3.471417   1.185901   1.288501
# 986   0.056046  0.158213  0.648367  0.052670  0.232023  16.306002   5.209082
# 1082  4.177513  0.138036  1.149841  2.564524  0.035085   0.156723   1.131085
# 32    4.201972  2.863204  3.831148  0.675132  0.140121   2.118683   4.877066
# 271   0.806194  1.610149  1.822584  0.276661  0.043721   0.387546   3.392658
#
# ...

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

clf = RandomForestClassifier(n_estimators= 100,max_depth=6, random_state=0)
clf.fit(X_train_new, Y_train)
# Out:
# RandomForestClassifier(max_depth=6, n_estimators=1000, random_state=0)

# %%
y_pred = clf.predict(X_test_new)

# %%
print("Training_Accuracy:",metrics.accuracy_score(Y_train,model.predict(X_train_new)))
print("Testing Accuracy:",metrics.accuracy_score(Y_test, y_pred))
print("Validation_Accuracy:",metrics.accuracy_score(Y_Val,model.predict(X_Val)))
# Out:
# Training_Accuracy: 1.0
# Testing Accuracy: 0.9404545454545454
# Validation_Accuracy: 0.71
