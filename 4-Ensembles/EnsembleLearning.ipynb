# %%
import pandas as pd
import numpy as np
from sklearn.ensemble import AdaBoostClassifier
from sklearn import datasets
from sklearn import metrics
# from random import shuffle
from sklearn.utils import shuffle

# %%
with open('project/pairsDevTrain.txt','r') as f:
    lines = f.readlines()

# %%
with open('project/pairsDevTest.txt','r') as f:
    lines_test = f.readlines()

# %%
counter = int(lines[0].replace('\n'," "))
name = []
index1 = []
index2 = []
for i in range(1,counter+1):
    test = lines[i].split("\t")
    n = test[0]
    i1 = test[1]
    i2 = test[2].split("\n")[0]
    name.append(n)
    index1.append(i1)
    index2.append(i2)
    
name1 = []
name2 = []
index3 = []
index4 = []
for i in range(counter+1,2*counter+1):
    test = lines[i].split("\t")
    n1 = test[0]
    n2 = test[2]
    i1 = test[1]
    i2 = test[3].split("\n")[0]
    name1.append(n1)
    name2.append(n2)
    index3.append(i1)
    index4.append(i2)

# %%
# test dataset
counter_test = int(lines_test[0].replace('\n'," "))
name_test = []
index1_test = []
index2_test = []
for i in range(1,counter_test+1):
    test = lines_test[i].split("\t")
    n = test[0]
    i1 = test[1]
    i2 = test[2].split("\n")[0]
    name_test.append(n)
    index1_test.append(i1)
    index2_test.append(i2)
    
name1_test = []
name2_test = []
index3_test = []
index4_test = []
for i in range(counter_test+1,2*counter_test+1):
    test = lines_test[i].split("\t")
    n1 = test[0]
    n2 = test[2]
    i1 = test[1]
    i2 = test[3].split("\n")[0]
    name1_test.append(n1)
    name2_test.append(n2)
    index3_test.append(i1)
    index4_test.append(i2)

# %%
d = {'name': name, 'pic1':index1, 'pic2':index2,'fet1':'','fet2':'','label':1}
df = pd.DataFrame(data=d)
df
# Out:
#                      name pic1 pic2 fet1 fet2  label
# 0           Aaron_Peirsol    1    2                1
# 1           Aaron_Peirsol    3    4                1
# 2            Aaron_Sorkin    1    2                1
# 3     Abdel_Nasser_Assidi    1    2                1
# 4                Abdullah    1    3                1
# ...                   ...  ...  ...  ...  ...    ...
# 1095           Zhu_Rongji    1    9                1
# 1096           Zhu_Rongji    4    7                1
# 1097           Zhu_Rongji    4    8                1
# 1098           Zhu_Rongji    5    6                1
# 1099      Zinedine_Zidane    2    4                1
#
# [1100 rows x 6 columns]

# %%
d1 = {'name': name1, 'name2':name2 ,'pic1':index3, 'pic2':index4,'fet1':'','fet2':'','label':0}
df_2 = pd.DataFrame(data=d1)
df_2
# Out:
#                      name                 name2 pic1 pic2 fet1 fet2  label
# 0                 AJ_Cook       Marsha_Thomason    1    1                0
# 1            Aaron_Sorkin          Frank_Solich    2    5                0
# 2     Abdel_Nasser_Assidi          Hilary_McKay    2    1                0
# 3          Abdoulaye_Wade            Linda_Dano    4    1                0
# 4            Abdul_Rahman           Magui_Serna    1    1                0
# ...                   ...                   ...  ...  ...  ...  ...    ...
# 1095          Tom_Vilsack        Wayne_Ferreira    1    5                0
# 1096         Trisha_Meili  Vladimiro_Montesinos    1    3                0
# 1097             Ty_Votaw          Wayne_Allard    1    1                0
# 1098       Vytas_Danelius        Zaini_Abdullah    1    1                0
# 1099        Wendy_Kennedy        Zara_Akhmadova    1    1                0
#
# [1100 rows x 7 columns]

# %%
d = {'name': name_test, 'pic1':index1_test, 'pic2':index2_test,'fet1':'','fet2':'','label':1}
df_test = pd.DataFrame(data=d)
df_test
# Out:
#                    name pic1 pic2 fet1 fet2  label
# 0          Abdullah_Gul   13   14                1
# 1          Abdullah_Gul   13   16                1
# 2      Abdullatif_Sener    1    2                1
# 3        Adel_Al-Jubeir    1    3                1
# 4             Al_Pacino    1    2                1
# ..                  ...  ...  ...  ...  ...    ...
# 495        Winona_Ryder    6   15                1
# 496        Winona_Ryder   19   21                1
# 497  Yevgeny_Kafelnikov    3    4                1
# 498    Yoriko_Kawaguchi    3   10                1
# 499      Zoran_Djindjic    3    4                1
#
# [500 rows x 6 columns]

# %%
d1 = {'name': name1_test, 'name2':name2_test ,'pic1':index3_test, 'pic2':index4_test,'fet1':'','fet2':'','label':0}
df_2_test = pd.DataFrame(data=d1)
df_2_test
# Out:
#                             name                         name2 pic1 pic2 fet1  \
# 0                       AJ_Lamas                   Zach_Safrin    1    1
# 1                    Aaron_Guiel             Reese_Witherspoon    1    3
# 2                   Aaron_Tippin  Jose_Luis_Rodriguez_Zapatero    1    1
# 3         Abdul_Majeed_Shobokshi                  Charles_Cope    1    1
# 4                   Abdullah_Gul                     Steve_Cox   16    1
# ..                           ...                           ...  ...  ...  ...
# 495                 Susan_Whelan         Wolfgang_Schneiderhan    1    1
# 496                  Takeo_Fukui               Will_Ofenheusle    1    1
# 497                 Tamara_Mowry                   Zach_Parise    1    1
# 498  Tatiana_Kennedy_Schlossberg                 Thomas_Watjen    1    1
# 499                   Todd_Petit             Vicente_Fernandez    1    3
#
#     fet2  label
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0
# ..   ...    ...
# 495           0
# 496           0
# 497           0
# 498           0
# 499           0
#
# [500 rows x 7 columns]

# %%
a2 = []
for i in range(counter):
    name = df['name'][i]
    pic1 = pic2 = test = test1 = ''
    a1 = []
    if int(df['pic1'][i]) >= 100:
        pic1 = name + '_' + '0'+ df['pic1'][i]
    elif 99>= int(df['pic1'][i]) >= 10:
        pic1 = name + '_' + '00'+ df['pic1'][i]
    else :
        pic1 = name + '_' + '000'+ df['pic1'][i]
        
    if int(df['pic2'][i]) >= 100 :
        pic2 = name + '_' + '0'+ df['pic2'][i]
    elif 99>int(df['pic2'][i]) >= 10 :
        pic2 = name + '_' + '00'+ df['pic2'][i]
    else :
        pic2 = name + '_' + '000'+ df['pic2'][i]
    with open('project/lfw/'+name+'/' +pic1 +'.txt','r') as f:
        test = f.read()
#         df['fet1'][i] =  test
        test = test.split("[[")[1]
        arr = test.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else: 
                a1.append(float(arr[i]))
        
        
    with open('project/lfw/'+name+'/' +pic2 +'.txt','r') as f:
        test1 = f.read()
#         df['fet2'][i] =  test1
        test1 = test1.split("[[")[1]
        arr = test1.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else: 
                a1.append(float(arr[i]))
                
                
    a2.append(a1)

# %%
df
# Out:
#                      name pic1 pic2 fet1 fet2  label
# 0           Aaron_Peirsol    1    2                1
# 1           Aaron_Peirsol    3    4                1
# 2            Aaron_Sorkin    1    2                1
# 3     Abdel_Nasser_Assidi    1    2                1
# 4                Abdullah    1    3                1
# ...                   ...  ...  ...  ...  ...    ...
# 1095           Zhu_Rongji    1    9                1
# 1096           Zhu_Rongji    4    7                1
# 1097           Zhu_Rongji    4    8                1
# 1098           Zhu_Rongji    5    6                1
# 1099      Zinedine_Zidane    2    4                1
#
# [1100 rows x 6 columns]

# %%
a3 = []

for i in range(counter):
    name1 = df_2['name'][i]
    name2 = df_2['name2'][i]
    pic1 = pic2 = test = test1 = ''
    a1 = []
    if int(df_2['pic1'][i]) >= 100:
        pic1 = name1 + '_' + '0'+ df_2['pic1'][i]
    elif 99>= int(df_2['pic1'][i]) >= 10:
        pic1 = name1 + '_' + '00'+ df_2['pic1'][i]
    else :
        pic1 = name1 + '_' + '000'+ df_2['pic1'][i]
        
    if int(df_2['pic2'][i]) >= 100 :
        pic2 = name2 + '_' + '0'+ df_2['pic2'][i]
    elif 99>int(df_2['pic2'][i]) >= 10 :
        pic2 = name2 + '_' + '00'+ df_2['pic2'][i]
    else :
        pic2 = name2 + '_' + '000'+ df_2['pic2'][i]
    with open('project/lfw/'+name1+'/' +pic1 +'.txt','r') as f:
        test = f.read()
#         df_2['fet1'][i] = test
        test = test.split("[[")[1]
        arr = test.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else: 
                a1.append(float(arr[i]))     
    with open('project/lfw/'+name2+'/' +pic2 +'.txt','r') as f:
        test1 = f.read()
#         df_2['fet2'][i] =  test1
        test1 = test1.split("[[")[1]
        arr = test1.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else:
                a1.append(float(arr[i]))
    a3.append(a1)

# %%
# test
a2_test = []
for i in range(counter_test):
    name = df_test['name'][i]
    pic1 = pic2 = test = test1 = ''
    a1 = []
    if int(df_test['pic1'][i]) >= 100:
        pic1 = name + '_' + '0'+ df_test['pic1'][i]
    elif 99>= int(df_test['pic1'][i]) >= 10:
        pic1 = name + '_' + '00'+ df_test['pic1'][i]
    else :
        pic1 = name + '_' + '000'+ df_test['pic1'][i]
        
    if int(df_test['pic2'][i]) >= 100 :
        pic2 = name + '_' + '0'+ df_test['pic2'][i]
    elif 99>int(df_test['pic2'][i]) >= 10 :
        pic2 = name + '_' + '00'+ df_test['pic2'][i]
    else :
        pic2 = name + '_' + '000'+ df_test['pic2'][i]
    with open('project/lfw/'+name+'/' +pic1 +'.txt','r') as f:
        test = f.read()
#         df_test['fet1'][i] =  test
        test = test.split("[[")[1]
        arr = test.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else: 
                a1.append(float(arr[i]))
        
        
    with open('project/lfw/'+name+'/' +pic2 +'.txt','r') as f:
        test1 = f.read()
#         df_test['fet2'][i] =  test1
        test1 = test1.split("[[")[1]
        arr = test1.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else: 
                a1.append(float(arr[i]))
                
                
    a2_test.append(a1)

# %%
a3_test = []

for i in range(counter_test):
    name1 = df_2_test['name'][i]
    name2 = df_2_test['name2'][i]
    pic1 = pic2 = test = test1 = ''
    a1 = []
    if int(df_2_test['pic1'][i]) >= 100:
        pic1 = name1 + '_' + '0'+ df_2_test['pic1'][i]
    elif 99>= int(df_2_test['pic1'][i]) >= 10:
        pic1 = name1 + '_' + '00'+ df_2_test['pic1'][i]
    else :
        pic1 = name1 + '_' + '000'+ df_2_test['pic1'][i]
        
    if int(df_2_test['pic2'][i]) >= 100 :
        pic2 = name2 + '_' + '0'+ df_2_test['pic2'][i]
    elif 99>int(df_2_test['pic2'][i]) >= 10 :
        pic2 = name2 + '_' + '00'+ df_2_test['pic2'][i]
    else :
        pic2 = name2 + '_' + '000'+ df_2_test['pic2'][i]
    with open('project/lfw/'+name1+'/' +pic1 +'.txt','r') as f:
        test = f.read()
#         df_2_test['fet1'][i] = test
        test = test.split("[[")[1]
        arr = test.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else: 
                a1.append(float(arr[i]))     
    with open('project/lfw/'+name2+'/' +pic2 +'.txt','r') as f:
        test1 = f.read()
#         df_2_test['fet2'][i] =  test1
        test1 = test1.split("[[")[1]
        arr = test1.replace("\n","").split(" ")
        for i in range(len(arr)):
            if arr[i] == '' :
                continue
            elif i == len(arr)-1:
                if arr[i] == ']]':
                    continue
                t = arr[i].split("]]")
                a1.append(float(t[0]))
            else:
                a1.append(float(arr[i]))
    a3_test.append(a1)

# %%
df_2.to_csv("df_2.csv")
df.to_csv("df.csv")

# %%
X_train1 = pd.DataFrame(a2)
X_train1
X_train2 = pd.DataFrame(a3)
X_train2
X1 = pd.concat([X_train1,df.iloc[:,5]],axis=1)
X1
X2 = pd.concat([X_train2,df_2.iloc[:,6]],axis=1)
X2

X_train = pd.concat([X1,X2],axis=0)
X_train
# Out:
#              0         1         2         3         4          5          6  \
# 0     0.943083  0.328070  5.107355  0.047781  6.151414   6.137378   2.698583
# 267  2.297870  4.744970  4.407265  ...  1.062689  4.689109  1.329282
# 278  1.824486  7.621773  0.000000  ...  1.500294  1.239292  0.213871
# 228  2.004792  1.883016  3.813228  ...  0.120255  3.477576  1.903261
# 192  0.198672  0.194275  2.769995  ...  3.390533  6.679424  2.134327
# 41   0.224438  0.615085  0.103057  ...  1.333720  3.155045  2.314332
#
#           1018      1019      1020      1021      1022      1023  label
# 395   1.696624  3.587564  0.711624  4.037845  3.256111  0.073027      1
# 144   2.303034  3.232632  1.227091  0.025847  3.226966  1.722507      1
# 362   8.499660  2.249899  1.751986  1.452321  5.180879  0.277634      1
# 128   4.385464  7.746350  1.899764  2.565768  0.434824  0.280333      1
# 332  14.872603  0.877729  0.463819  0.670400  5.113144  5.238579      1
# ..         ...       ...       ...       ...       ...       ...    ...
# 267   8.385402  5.787738  1.162828  0.392178  5.909230  0.000000      0
# 278   9.794422  1.062206  0.233273  0.000000  0.950349  0.251386      1
# 228   4.896038  1.158021  2.829205  0.990996  8.262876  9.004471      1
# 192  10.163449  0.504507  1.807930  0.000000  6.630544  2.145999      1
# 41    7.293406  2.174202  2.455605  2.349459  7.500938  3.153389      0
#
# [1000 rows x 1025 columns]

# %%
X_test_new = X_train.iloc[:,:1024]
Y_test = X_train.iloc[:,1024]
Y_test
# Out:
# 424    0
# 201    0
# 942    1
# 696    1
# 497    1
#       ..
# 674    0
# 343    1
# 41     1
# 807    1
# 370    1
# Name: label, Length: 2200, dtype: int64

# %%
# 5749
from sklearn.tree import DecisionTreeClassifier
decision_tree = DecisionTreeClassifier(random_state=0, max_depth=2)
abc = AdaBoostClassifier(base_estimator=decision_tree, n_estimators=200,learning_rate=1)

# Train Adaboost Classifer
model = abc.fit(X_train_new, Y_train)

# %%
#Predict the response for test dataset
y_pred = model.predict(X_test_new)

# %%
print("Training_Accuracy:",metrics.accuracy_score(Y_train,model.predict(X_train_new)))
print("Testing Accuracy:",metrics.accuracy_score(Y_test, y_pred))
print("Validation_Accuracy:",metrics.accuracy_score(Y_Val,model.predict(X_Val)))
# Out:
# Training_Accuracy: 1.0
# Testing Accuracy: 0.9390909090909091
# Validation_Accuracy: 0.665

# %% [markdown]
# # AdaBoost with SVC

# %%
# Load libraries
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn import metrics


svc=SVC(probability=True, kernel='rbf')

# Create adaboost classifer object
abc =AdaBoostClassifier(n_estimators=50, base_estimator=svc,learning_rate=1)

# Train Adaboost Classifer
model = abc.fit(X_train_new, Y_train)

#Predict the response for test dataset
y_pred = model.predict(X_test_new)

# %%
print("Training_Accuracy:",metrics.accuracy_score(Y_train,model.predict(X_train_new)))
print("Testing Accuracy:",metrics.accuracy_score(Y_test, y_pred))
print("Validation_Accuracy:",metrics.accuracy_score(Y_Val,model.predict(X_Val)))
# Out:
# Training_Accuracy: 0.995
# Testing Accuracy: 0.9431818181818182
# Validation_Accuracy: 0.71

# %%
X_train_new
# Out:
#          0         1         2         3         4         5          6     \
# 424  0.922690  1.472656  0.329833  0.764208  0.894644  8.734124   6.086827
# 201  1.771580  2.175807  0.000000  0.196917  0.466702  1.726108   8.924177
# 942  0.064955  0.687543  5.990353  0.214168  1.577035  9.063090   5.829591
# 696  0.000000  0.896913  0.113296  0.000000  0.000000  2.202793   4.968699
# 497  0.306910  2.116782  4.213968  0.000000  2.886824  6.974339   4.840481
# ..        ...       ...       ...       ...       ...       ...        ...
# 376  0.952726  2.991400  4.797401  0.000000  0.352312  1.102148   3.684948
# 528  3.972816  0.971883  0.432489  0.137985  1.103673  2.557741   7.230690
# 523  4.764622  1.142761  0.162733  0.407679  0.399310  7.310459  18.141052
# 889  1.663036  0.332162  6.631960  0.345858  0.076051  0.430237   1.699276
# 647  1.736766  2.502814  1.648586  0.062510  0.000000  3.069816   5.085874
#
#          7         8         9     ...      1014      1015      1016  \
# 424  1.954731  2.377281  1.438097  ...  0.000000  3.345764  3.432221
# 201  0.038180  0.646813  0.014775  ...  5.577553  3.270368  2.825516
# 942  0.490681  0.869286  6.718079  ...  2.653469  2.716529  1.510474
# 696  1.949631  0.811624  1.164052  ...  4.015005  8.716613  3.519190
# 497  1.161896  0.780072  1.292247  ...  0.477254  0.224395  3.628201
# ..        ...       ...       ...  ...       ...       ...       ...
# 376  5.069903  4.358322  4.355152  ...  0.000000  3.842527  6.385532
# 528  0.466532  0.399853  0.002791  ...  5.262289  2.541861  7.684934
# 523  0.000000  0.187080  0.590681  ...  7.783669  8.134260  4.974231
# 889  7.557103  4.257052  0.968666  ...  1.027330  0.108093  0.936334
# 647  0.936640  0.503006  0.746109  ...  0.906542  0.868337  2.666396
#
#          1017      1018      1019      1020      1021      1022      1023
# 424  0.153965  7.396088  5.653394  0.675927  0.507218  0.005095  0.232020
# 201  2.066752  2.107433  5.357678  0.000000  0.897010  6.164690  0.000000
# 942  0.191793  1.457613  6.032616  1.601571  2.083280  3.060474  2.064133
# 696  1.476354  2.289749  0.253627  0.025467  0.000000  6.225048  0.013268
# 497  1.759862  0.962625  1.316486  0.912129  0.348376  1.291949  0.204644
# ..        ...       ...       ...       ...       ...       ...       ...
# 376  0.719739  3.766157  3.642155  0.696052  0.246034  6.837833  5.788250
# 528  0.153725  0.938747  6.413991  1.337361  1.522063  4.449574  4.875617
# 523  0.951858  2.399863  0.042067  0.438649  0.000000  2.326155  4.016305
# 889  2.529723  1.570481  1.391779  3.762258  1.604404  2.831330  1.418786
# 647  2.763653  6.186615  2.088937  0.965726  1.566578  4.486074  0.738136
#
# [1800 rows x 1024 columns]

# %% [markdown]
# # Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier
import numpy

clf = RandomForestClassifier(n_estimators= 500,criterion= 'entropy',max_depth=5, random_state=0)
clf.fit(X_train_new, Y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=5, n_estimators=500,
#                        random_state=0)

# %%
y_pred = clf.predict(X_test_new)

# %%
print("Training_Accuracy:",metrics.accuracy_score(Y_train,clf.predict(X_train_new)))
print("Testing Accuracy:",metrics.accuracy_score(Y_test, y_pred))
print("Validation_Accuracy:",metrics.accuracy_score(Y_Val,clf.predict(X_Val)))
# Out:
# Training_Accuracy: 0.99
# Testing Accuracy: 0.9286363636363636
# Validation_Accuracy: 0.6525
